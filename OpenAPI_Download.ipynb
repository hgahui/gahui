# %%
import requests
import pprint

# %%
encoding = 'znbXfiw3UrwenyYUOiKN%2FMYB18cgELxI6oHT1raf3jXCpFnLqG%2FhvEv097T2%2BK2fHdUhRAwuNuPEzxLCdZeelg%3D%3D'
decoding = 'znbXfiw3UrwenyYUOiKN/MYB18cgELxI6oHT1raf3jXCpFnLqG/hvEv097T2+K2fHdUhRAwuNuPEzxLCdZeelg=='

# %%
url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/storeZoneInAdmi'
params = {'serviceKey' : decoding ,
          'key' : '12',
          'type' : 'xml' }

response = requests.get(url, params=params, verify=False)

content = response.text

pp = pprint.PrettyPrinter(indent=4)

# %%
from os import name
import xml.etree.ElementTree as et
import pandas as pd
import bs4
from lxml import html
from urllib.parse import urlencode, quote_plus, unquote

# %%
xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
rows = xml_obj.findAll('item')
print(rows)
# Out:
# [<item>
# <trarNo>9221</trarNo>
# <mainTrarNm>구로중앙유통단지</mainTrarNm>
# <ctprvnCd>11</ctprvnCd>
# <ctprvnNm>서울특별시</ctprvnNm>
# <signguCd>11530</signguCd>
# <signguNm>구로구</signguNm>
# <trarArea>104600</trarArea>
# <coordNum>43</coordNum>
# ...

# %%
row_list = []
name_list = []
value_list = []

for i in range(0, len(rows)):
  columns = rows[i].find_all()
  for j in range(0, len(columns)):
    if i == 0:
      name_list.append(columns[j].name)
    value_list.append(columns[j].text)
  row_list.append(value_list)
  value_list = []

# %%
sdsc2_key11_df = pd.DataFrame(row_list, columns=name_list)
print(sdsc2_df.head())
# Out:
#   trarNo       mainTrarNm ctprvnCd ctprvnNm signguCd signguNm trarArea  \
# 0   9221         구로중앙유통단지       11    서울특별시    11530      구로구   104600
# 1   9222              대림역       11    서울특별시    11530      구로구    20916
# 2   9213  가리봉시장(구로디지털오거리)       11    서울특별시    11530      구로구    26424
# 3   9223             신도림역       11    서울특별시    11530      구로구   154677
# 4   9224              오류동       11    서울특별시    11530      구로구    84263
#
#   coordNum                                             coords      stdrDt
# 0       43  MULTIPOLYGON (((126.873773094011 37.5041208594...  2021-06-30
# 1       21  MULTIPOLYGON (((126.889410453306 37.4953953971...  2021-06-30
# 2       24  MULTIPOLYGON (((126.888699631543 37.4830419883...  2021-06-30
# 3       53  MULTIPOLYGON (((126.888977556373 37.5107232411...  2021-06-30
# 4       51  MULTIPOLYGON (((126.842502847581 37.4973148187...  2021-06-30

# %%
sdsc2_key11_df.to_csv('sdsc2_key11.csv', encoding='utf-8-sig')

# %%
from google.colab import files

# %%
files.download('sdsc2_key11.csv')

# %%
import requests
import pprint

encoding = 'znbXfiw3UrwenyYUOiKN%2FMYB18cgELxI6oHT1raf3jXCpFnLqG%2FhvEv097T2%2BK2fHdUhRAwuNuPEzxLCdZeelg%3D%3D'
decoding = 'znbXfiw3UrwenyYUOiKN/MYB18cgELxI6oHT1raf3jXCpFnLqG/hvEv097T2+K2fHdUhRAwuNuPEzxLCdZeelg=='

url = 'http://apis.data.go.kr/1160100/service/GetStocIssuInfoService_V2/getStocIssuInfo_V2'
params = {'serviceKey' : decoding,
          'pageNo' : '1',
          'numOfRows' : '100',
          'resultType' : 'xml',
          'basDt' : '20231201'}

response = requests.get(url, params=params, verify=False)

content = response.text

pp = pprint.PrettyPrinter(indent=4)
print(pp.pprint(content))

from os import name
import xml.etree.ElementTree as et
import pandas as pd
import bs4
from lxml import html
from urllib.parse import urlencode, quote_plus, unquote

xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
rows = xml_obj.findAll('item')
print(rows)

row_list = []
name_list = []
value_list = []

for i in range(0, len(rows)):
  columns = rows[i].find_all()
  for j in range(0, len(columns)):
    if i == 0:
      name_list.append(columns[j].name)
    value_list.append(columns[j].text)
  row_list.append(value_list)
  value_list = []

stocinfo_df = pd.DataFrame(row_list, columns=name_list)
print(stocinfo_df.head())

stocinfo_df.to_csv('stocinfo.csv', encoding='utf-8-sig')

from google.colab import files
files.download('stocinfo.csv')
# Out:
# ('<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n'
#  '<response>\n'
#  '    <header>\n'
#  '        <resultCode>00</resultCode>\n'
#  '        <resultMsg>NORMAL SERVICE.</resultMsg>\n'
#  '    </header>\n'
#  '    <body>\n'
#  '        <numOfRows>100</numOfRows>\n'
#  '        <pageNo>1</pageNo>\n'
#  '        <totalCount>0</totalCount>\n'
#  '        <items/>\n'
#  '    </body>\n'
#  '</response>\n')
# None
# []

# %%
import requests
import pprint

encoding = 'znbXfiw3UrwenyYUOiKN%2FMYB18cgELxI6oHT1raf3jXCpFnLqG%2FhvEv097T2%2BK2fHdUhRAwuNuPEzxLCdZeelg%3D%3D'
decoding = 'znbXfiw3UrwenyYUOiKN/MYB18cgELxI6oHT1raf3jXCpFnLqG/hvEv097T2+K2fHdUhRAwuNuPEzxLCdZeelg=='

url = 'http://apis.data.go.kr/1360000/TourStnInfoService1/getCityTourClmIdx1'
params = {'serviceKey' : decoding,
          'pageNo' : '1',
          'numOfRows' : '50000',
          'CURRENT_DATE' : '2018123110',
          # 'DAY' : '20231130',
          # 'base_time' : '0500',
          # 'nx' : '55',
          'DAY' : '1280'
          }

response = requests.get(url, params=params, verify=False)

content = response.text

pp = pprint.PrettyPrinter(indent=4)
# print(pp.pprint(content))

from os import name
import xml.etree.ElementTree as et
import pandas as pd
import bs4
from lxml import html
from urllib.parse import urlencode, quote_plus, unquote

xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
rows = xml_obj.findAll('item')
# print(rows)

row_list = []
name_list = []
value_list = []

for i in range(0, len(rows)):
  columns = rows[i].find_all()
  for j in range(0, len(columns)):
    if i == 0:
      name_list.append(columns[j].name)
    value_list.append(columns[j].text)
  row_list.append(value_list)
  value_list = []

cityclmid_df = pd.DataFrame(row_list, columns=name_list)
print(cityclmid_df.head())

cityclmid_df.to_csv('cityclmid.csv', encoding='utf-8-sig')

from google.colab import files
files.download('cityclmid.csv')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
encoding = 'znbXfiw3UrwenyYUOiKN%2FMYB18cgELxI6oHT1raf3jXCpFnLqG%2FhvEv097T2%2BK2fHdUhRAwuNuPEzxLCdZeelg%3D%3D'
decoding = 'znbXfiw3UrwenyYUOiKN/MYB18cgELxI6oHT1raf3jXCpFnLqG/hvEv097T2+K2fHdUhRAwuNuPEzxLCdZeelg=='

url = 'http://apis.data.go.kr/1262000/AccidentService/getAccidentList'
params = {'serviceKey' : decoding,
          'numOfRows' : '10000',
          'pageNo' : '1'
          # 'routeNo' : '564'
          # 'searchYearCd' : '2017',
          # 'siDo' : '11',
          # 'guGun' : '110',
          # 'type' : 'xml',
          # 'nx' : '55',
          # 'numOfRows' : '10',
          # 'pageNo' : '1'
          # 'DAY' : '1280'
          }

response = requests.get(url, params=params, verify=False)

content = response.text

pp = pprint.PrettyPrinter(indent=4)
print(pp.pprint(content))

xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
rows = xml_obj.findAll('item')
print(rows)

row_list = []
name_list = []
value_list = []

for i in range(0, len(rows)):
  columns = rows[i].find_all()
  for j in range(0, len(columns)):
    if i == 0:
      name_list.append(columns[j].name)
    value_list.append(columns[j].text)
  row_list.append(value_list)
  value_list = []

accidientlst_df = pd.DataFrame(row_list, columns=name_list)
print(accidientlst_df.head())

accidientlst_df.to_csv('accidientlst.csv', encoding='utf-8-sig')

from google.colab import files
files.download('accidientlst.csv')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ㅇ 2005.1월 동남아 지역에 발생한 지진해일(쓰나미)로 남부 푸켓지방에 인명 및 막대한 재산피해 발생(사망5,395명 실종 2,817명)&lt;br&gt;
# ㅇ 2010.10월 홍수로 사망자 98명, 이재민 약2백만명 발생&lt;br&gt;&lt;br&gt;
#
# &lt;h3 class="tit"&gt;유의해야할 지역&lt;/h3&gt;
# [소매치기 유의지역]&lt;br&gt;
# ㅇ 방콕, 푸켓, 파타야 등 외국인 다수 방문지역에 소매치기 , 오토바이날치기로 인한 피해가 빈발하고 있으니 가방, 여권, 지갑 등 소지품 관리에 유의하여 주시기 바랍니다.&lt;br&gt;&lt;/div&gt;</news><wrtDt>2011-08-04</wrtDt></item>, <item><continent>유럽</continent><ename>Georgia</ename><id>332</id><imgUrl>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=COUNTRY_332&amp;file_sn=1</imgUrl><imgUrl2>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=COUNTRY_332&amp;file_sn=3</imgUrl2><name>조지아</name><news>&lt;div&gt;&lt;h3 class="tit"&gt;※ 안전유의 당부&lt;/h3&gt;
# ...

# %%
encoding = 'znbXfiw3UrwenyYUOiKN%2FMYB18cgELxI6oHT1raf3jXCpFnLqG%2FhvEv097T2%2BK2fHdUhRAwuNuPEzxLCdZeelg%3D%3D'
decoding = 'znbXfiw3UrwenyYUOiKN/MYB18cgELxI6oHT1raf3jXCpFnLqG/hvEv097T2+K2fHdUhRAwuNuPEzxLCdZeelg=='

url = 'http://www.emuseum.go.kr/openapi/relic/list'
params = {'serviceKey' : decoding,
          'pageNo' : '1',
          'numOfRows' : '10000'}

response = requests.get(url, params=params, verify=False)

content = response.text

pp = pprint.PrettyPrinter(indent=4)
print(pp.pprint(content))

xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
rows = xml_obj.findAll('item')
print(rows)

row_list = []
name_list = []
value_list = []

for i in range(0, len(rows)):
  columns = rows[i].find_all()
  for j in range(0, len(columns)):
    if i == 0:
      name_list.append(columns[j].name)
    value_list.append(columns[j].text)
  row_list.append(value_list)
  value_list = []

treaslst_df = pd.DataFrame(row_list, columns=name_list)
print(treaslst_df.head())

treaslst_df.to_csv('treaslst.csv', encoding='utf-8-sig')

files.download('treaslst.csv')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
encoding = 'znbXfiw3UrwenyYUOiKN%2FMYB18cgELxI6oHT1raf3jXCpFnLqG%2FhvEv097T2%2BK2fHdUhRAwuNuPEzxLCdZeelg%3D%3D'
decoding = 'znbXfiw3UrwenyYUOiKN/MYB18cgELxI6oHT1raf3jXCpFnLqG/hvEv097T2+K2fHdUhRAwuNuPEzxLCdZeelg=='

url = 'http://apis.data.go.kr/1051000/fclt/list'
params = {'serviceKey' : decoding}

response = requests.get(url, params=params, verify=False)

content = response.text

pp = pprint.PrettyPrinter(indent=4)
# print(pp.pprint(content))

xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
rows = xml_obj.findAll('item')
print(rows)

row_list = []
name_list = []
value_list = []

for i in range(0, len(rows)):
  columns = rows[i].find_all()
  for j in range(0, len(columns)):
    if i == 0:
      name_list.append(columns[j].name)
    value_list.append(columns[j].text)
  row_list.append(value_list)
  value_list = []

fcltlist_df = pd.DataFrame(row_list, columns=name_list)
print(fcltlist_df.head())

fcltlist_df.to_csv('fcltlist.csv', encoding='utf-8-sig')

from google.colab import files
files.download('fcltlist.csv')
# Out:
# []
# Empty DataFrame
# Columns: []
# Index: []
